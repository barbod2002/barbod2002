# %%
#my problem in my daily life is that i don't have a healthy food diet and i don't have time to search on the internet every day to see what should i eat. however today i want to write a code which give advises about what should i eat and what shoudn't i eat based on my BMI and some other information.
import datetime
import sys
tm = datetime.datetime.now()
print ("TIME & DATE:",tm.strftime("%Y-%m-%d %H:%M:%S"))
# in this parti just want to give the date and time to the person who is running it
print()
print("""hi!
we hope that you are doing great 👍 
in this program we will help you to find the best daily plan base on your food diet""")
print()
while True:
    q1 = input("do you want to Continue?(type YES or NO)")
    if q1.upper() == "YES":
        print("Great let's start")
        break
    elif q1.upper() == "NO":
        print("Thats sad to hear,but Don't worry I am here if you need me.")
        sys.exit()
    else:
        print("sorry didn't understand ")
#in this section i am asking if you want to continue or not. If the person answers no, the code will stop running        
#if the given answer isn't correct, it will ask again till the user answers correctly        
    
print()
print("Let's Start, Just answer the following questions!")
print()

print()
print("""So in the following questions we are going to ask you about your height and weight; therefore, please have this information ready.
     
     
     Lets calculate your BMI""")
print()
while True:
    q2 = input("do you want to enter your height in Foot and inches?(Yes or No)")
    if q1.upper() == "YES":
        break
    elif q1.upper() == "NO":
        break
    else:
        print("sorry, i didn't understand, please try again!")

if q2.upper() =="YES":
    height_foot = float(input("Input your height in feet then input the inch part in next blank: "))
    height_1 = height_foot * 30.48
    height_inches = float(input("Input your height inch:"))
    height_2 = height_inches * 2.54
    height = height_1 + height_2
elif q2.upper() =="NO":
    height_cm = float(input("Input your height in cm: "))
    height = height_cm * 1
print()
weight = float(input("Input your weight in Kilogram: "))
print()
BMI = weight / (height/100)**2
print("Your BMI is: ", BMI)
print()
#Up to this Section, I asked the user to give personal information, to calculate the person's BMI. 

lw = 24.9 * ((height/100)**2) 
w = 18.5 - BMI
gw = w*((height/100)**2) 

# At this section, I want to see whether the person is over 24.9 or not. So to calculate how much weight the person need to lose weight to reach 24.9
# Also I calculated if the user is under 18.5 or no. So to calculate how much weight the person needs to gain to reach 18.5
print()
             
print("PLEASE ANSWER THE FOLLOWING QUESTIONS")

while True:
    
    Excercise = str(input("""How often do you exercise? 
    A.Once a week 
    B.Twice a week 
    C.One day in between 
    D.every weekdays 
    E.every weekend 
    F.everyday
    G.Never
    my answer:"""))
    result = Excercise.title()
    ex = 0
    if result == "A":
        print("try more exercising it's good for your health")
        ex == 1
        break
    elif result == "B":
        print("try more exercise it's good for your health")
        ex == 2
        break
    elif result == "C":
        print("try more exercise;however It's still good" )
        ex == 3
        break
    elif result == "D":
        print("keep the good job 👍")
        ex == 5
        break
    elif result == "E":
        print("try more exercise during the week, it's good for your health")
        ex == 2
        break
    elif result == "F":
        print("amazing 👌🤩")
        ex == 7
        break
    elif result == "G":
        print("it's not good at all, you are going to gain lots of weight if you don't exercise often.")
        ex == 0
        break
    else: 
        print("I dont understand, Try again")
        
#IN this section, i asked how often does the user exercise and if the given answer isn't one of the above, it will ask again till the user answers correctly
        
print()
#The section below is about the user's sleep hours.
sleep = float(input("How many hours do you sleep usually?(e.g. 6.5 , 8.5 , 5,...) ")) 
      
if sleep <= 6.5:
    print("you have to sleep more because your body is going to be week")
elif sleep >= 7 and sleep <= 8.5:
    print("you have enough sleep during the night")
else:
    print("it is more than enough for your body therefore you are going to be slugish during the day and you won't enjoy your day and also it is not healthy to sleep more than enough")
print() 

# What is your current diet?

Diet = str(input("""What does your current diet consist of?
A. Vegan or Vegetarian 
B. Main source of protein is from meat
C. Mainly carbohydrates
D. Fatty food, such as fast food
"""))
print()


#after this section, The computer will collect information and give the best food diet plan to the user based on their given answers and BMI. 


print("let gives you some advices to keep it in your daily food diet")
print("first of all you have to check your weight once a week and check your BMI ")


if 18.5 <= BMI < 19.5:
    print("you are doing great but be carefull if you lose more weight it not good;Therefore, for gaining weight you have to eat more proteins and carbohydrates but be carefull to don't eat too much,just enough.")
elif 19.5<=BMI<25 :
    print("keep the good working and Don't forget to eat healthy and have enough sleep during a day and exercise at least 30 min per day")

elif 25.0 <= BMI < 30 and (sleep <= 6.5 or sleep >= 8.5) and (ex == 1 or ex == 2 or ex == 3 or ex == 5 or ex == 7  or ex == 0) and(Diet.upper() == "C" or Diet.upper() == "B" or Diet.upper() == "D"):
    print("read this carefully ")
    for i in range (0,3):
        print("🛑👇🛑")
    for r in range(2):
        print()
    print("you are overweight. Therefore you have to lose weight to reach the average BMI. so for reaching the BMI of 24.9 or lower you have to reach to",lw,"""kg to be healthy.
          For losing weight, the best way is to go to gym and have a good food diet and do inside or outside walking at least 3o minutes per day
          a study published in the New England Journal of Medicine found that foods like potato chips, processed meats, red meat, and sugary beverages were associated with weight gain, 
          while those like fruits, veggies, whole grains, nuts, and yogurt were associated with weight loss. Drinking lots of water can also play a huge role in losing or maintaining healthy weight.
          try to do as much exercise as Possible during the day.
          So for today i really recommend you to have enough sleep and remove any meet and carbohydrate from your food for a whole week and even if you want you can only use grain bread 🍞 every two days. exercise at least 1 hour per day
          Eat More Fruits, Vegetables, Whole Grains, and Low- or No-Fat Dairy Products Every Day
          
          1-Aim for at least five servings of fruits and vegetables a day. 
          2-Try and choose whole grain cereal, pasta, rice, and bread. 
          3-Avoid food that is high in sugar, like pastries, sweetened cereal, and soda or fruit-flavored drinks.
          
          do these things and you will see your body will be healthier 
          
          Foods to Help You Lose Weight:👇
          
          Beans. Inexpensive, filling, and versatile, beans are a
          great source of protein.
          Soup. Start a meal with a cup of soup, and you may end up eating less.
          Dark Chocolate. 
          Pureed Vegetables.
          Nuts.
          Apples.
          Yogurt.""")
    
elif 25.0 <= BMI < 30 and (sleep >= 7 and sleep <= 8.5) and (ex == 1 or ex == 2 or ex == 3 or ex == 5 or ex == 7  or ex == 0 ) and(Diet.upper() == "C" or Diet.upper() == "B" or Diet.upper() == "D"):
    print("read this carefully ")
    for i in range (0,3):
        print("🛑👇🛑")
    for r in range(2):
        print()
    print("you are Overweight. Therefore you have to lose weight to reach the average BMI. so for reaching the BMI of 24.9 or lower you have to lose at least",lw,"""kg to be healthy.
          For losing weight, the best way is to go to gym and have a good food diet and do inside or outside walking at least 3o minutes per day
          a study published in the New England Journal of Medicine found that foods like potato chips, processed meats, red meat, and sugary beverages were associated with weight gain, 
          while those like fruits, veggies, whole grains, nuts, and yogurt were associated with weight loss. Drinking lots of water can also play a huge role in losing or maintaining healthy weight.
          try to do as much exercise as Possible during the day.
          So for today i really recommend you to remove any meet and carbohydrate from your food for a whole week and even if you want you can only use grain bread 🍞 every two days. you have enogh sleep and it is good for your body keep up the good working😊. exercise at least 1 hour per day
          Eat More Fruits, Vegetables, Whole Grains, and Low- or No-Fat Dairy Products Every Day
          
          1-Aim for at least five servings of fruits and vegetables a day. ... 
          2-Try and choose whole grain cereal, pasta, rice, and bread. ... 
          3-Avoid food that is high in sugar, like pastries, sweetened cereal, and soda or fruit-flavored drinks.
          
          do these things and you will see your body will be healthier
          
          Foods to Help You Lose Weight:👇
          
          Beans. Inexpensive, filling, and versatile, beans are a
          great source of protein.
          Soup. Start a meal with a cup of soup, and you may end up eating less.
          Dark Chocolate. 
          Pureed Vegetables.
          Nuts.
          Apples.
          Yogurt.""")
    
elif 30 <= BMI  and (sleep <= 6.5 or sleep >= 8.5) and (ex == 1 or ex == 2 or ex == 3 or ex == 5 or ex == 7  or ex == 0 ) and(Diet.upper() == "C" or Diet.upper() == "B" or Diet.upper() == "D"):
    print("read this carefully ")
    for i in range (0,4):
        print("🛑👇🛑")
    for r in range(2):
        print()
        
    print("you are Obese. Therefore you have to lose weight to reach the average BMI. so for reaching the BMI of 24.9 or lower you have to lose at least",lw,"""kg to be healthy.
          For losing weight, the best way is to go to gym and have a good food diet and do inside or outside walking at least 3o minutes per day
          a study published in the New England Journal of Medicine found that foods like potato chips, processed meats, red meat, and sugary beverages were associated with weight gain, 
          while those like fruits, veggies, whole grains, nuts, and yogurt were associated with weight loss. Drinking lots of water can also play a huge role in losing or maintaining healthy weight.
          try to do as much exercise as Possible during the day.
          So for today i really recommend you to have enough sleep and remove any meet and carbohydrate from your food for a whole week and even if you want you can only use grain bread 🍞 every two days. exercise at least 1 hour per day. you don't have enough sleep.😔
          Eat More Fruits, Vegetables, Whole Grains, and Low- or No-Fat Dairy Products Every Day
          
          1-Aim for at least five servings of fruits and vegetables a day.
          2-Try and choose whole grain cereal, pasta, rice, and bread. 
          3-Avoid food that is high in sugar, like pastries, sweetened cereal, and soda or fruit-flavored drinks.
          
          do these things and you will see your body will be healthier
          
          Foods to Help You Lose Weight:👇
          
          Beans. Inexpensive, filling, and versatile, beans are a
          great source of protein.
          Soup. Start a meal with a cup of soup, and you may end up eating less.
          Dark Chocolate. 
          Pureed Vegetables.
          Nuts.
          Apples.
          Yogurt.""")

elif 30 <= BMI  and (sleep >= 7 and sleep <= 8.5) and (ex == 1 or ex == 2 or ex == 3 or ex == 5 or ex == 7  or ex == 0 ) and(Diet.upper() == "C" or Diet.upper() == "B" or Diet.upper() == "D"):
    print("read this carefully ")
    for i in range (0,4):
        print("🛑👇🛑")
    for r in range(2):
        print()
        
    print("you are Obese. Therefore you have to lose weight to reach the average BMI. so for reaching the BMI of 24.9 or lower you have to lose at least",lw,"""kg to be healthy.
          For losing weight, the best way is to go to gym and have a good food diet and do inside or outside walking at least 3o minutes per day
          a study published in the New England Journal of Medicine found that foods like potato chips, processed meats, red meat, and sugary beverages were associated with weight gain, 
          while those like fruits, veggies, whole grains, nuts, and yogurt were associated with weight loss. Drinking lots of water can also play a huge role in losing or maintaining healthy weight.
          try to do as much exercise as Possible during the day.
          So for today i really recommend you to have enough sleep and remove any meet and carbohydrate from your food for a whole week and even if you want you can only use grain bread 🍞 every two days. exercise at least 1 hour per day. you have enogh sleep and it is good for your body keep up the good working😊.
          Eat More Fruits, Vegetables, Whole Grains, and Low- or No-Fat Dairy Products Every Day
          
          1-Aim for at least five servings of fruits and vegetables a day. 
          2-Try and choose whole grain cereal, pasta, rice, and bread. 
          3-Avoid food that is high in sugar, like pastries, sweetened cereal, and soda or fruit-flavored drinks.
          
          do these things and you will see your body will be healthier
          
          Foods to Help You Lose Weight:👇
          
          Beans. Inexpensive, filling, and versatile, beans are a
          great source of protein.
          Soup. Start a meal with a cup of soup, and you may end up eating less.
          Dark Chocolate. 
          Pureed Vegetables.
          Nuts.
          Apples.
          Yogurt.""")

    
elif BMI< 18.5:
    print("you are Underweight have to gain weight or you are going get indigestion.you have to gain at least",int(gw),"""kg to become Healthy
    
    Foods you can eat to gain weight:👇
    
    Homemade protein smoothies. Drinking homemade
    protein smoothies can be a highly nutritious and quick
    way to gain weight.
    Milk.
    Rice.
    Red meats.
    Potatoes and starches.
    Salmon and oily fish.
    Protein supplements.
    """)
# Out:
# TIME & DATE: 2022-03-29 17:34:30
#
# hi!
# we hope that you are doing great 👍
# in this program we will help you to find the best daily plan base on your food diet
#
# do you want to Continue?(type YES or NO)yes
# Great let's start
#
# Let's Start, Just answer the following questions!
#
#
# So in the following questions we are going to ask you about your height and weight; therefore, please have this information ready.
#
#
#      Lets calculate your BMI
#
# do you want to enter your height in Foot and inches?(Yes or No)yes
# Input your height in feet then input the inch part in next blank: 6
# Input your height inch:2
#
# Input your weight in Kilogram: 90
#
# Your BMI is:  25.474850073147916
#
#
# PLEASE ANSWER THE FOLLOWING QUESTIONS
# How often do you exercise?
#     A.Once a week
#     B.Twice a week
#     C.One day in between
#     D.every weekdays
#     E.every weekend
#     F.everyday
#     G.Never
#     my answer:d
# keep the good job 👍
#
# ...
